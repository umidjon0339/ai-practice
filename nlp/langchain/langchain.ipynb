# %%
# !pip install langchain-google-genai python-dotenv
# Out:
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-4.3.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dotenv in /home/matimatik/anaconda3/lib/python3.13/site-packages (1.2.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<3.0.0,>=1.65.0 (from langchain-google-genai)
#   Using cached google_genai-2.16.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-google-genai) (1.5.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-google-genai) (2.12.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.10.0)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached google_auth-2.56.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.0.0 (from langchain-google-genai)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (46.0.3)
# Requirement already satisfied: certifi in /home/matimatik/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/matimatik/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.6.0)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.0.0->langchain-google-genai)
#   Using cached pydantic_core-2.46.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /home/matimatik/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/matimatik/anaconda3/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.1)
# Using cached langchain_google_genai-4.3.2-py3-none-any.whl (72 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_genai-2.16.0-py3-none-any.whl (1.1 MB)
# Using cached google_auth-2.56.2-py3-none-any.whl (258 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Installing collected packages: filetype, pydantic-core, pydantic, google-auth, google-genai, langchain-google-genai
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.5
#     Uninstalling pydantic_core-2.41.5:
#       Successfully uninstalled pydantic_core-2.41.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.4━━━━━━━━━━━━━━━━━━ 2/6 [pydantic]
#     Uninstalling pydantic-2.12.4:90m━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [pydantic]
#       Successfully uninstalled pydantic-2.12.4━━━━━━━━━━━━━━━━ 2/6 [pydantic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langchain-google-genai]e-genai]
# Successfully installed filetype-1.2.0 google-auth-2.56.2 google-genai-2.16.0 langchain-google-genai-4.3.2 pydantic-2.13.4 pydantic-core-2.46.4

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model(
    "gemini-2.5-flash",
    model_provider="google_genai",
    temperature=0.7,
)

prompt = """
Write a professional email.

Recipient: My manager
Reason: I am sick.
Leave Duration: 2 days.
Tone: Formal.

Include:
- Subject
- Greeting
- Body
- Closing
"""

response = model.invoke(prompt)

print("=" * 60)
print("AI GENERATED EMAIL")
print("=" * 60)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3379, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3378 try:
# -> 3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/models.py:6602, in Models.generate_content(self, model, contents, config)
#    6601 i += 1
# -> 6602 response = self._generate_content(
#    6603     model=model, contents=contents, config=parsed_config_to_call
#    6604 )
#    6606 if not function_map:
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/models.py:5028, in Models._generate_content(self, model, contents, config)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1705 http_request = self._build_request(
#    1706     http_method, path, request_dict, http_options
#    1707 )
# -> 1708 response = self._request(http_request, http_options, stream=False)
#    1709 response_body = (
#    1710     response.response_stream[0] if response.response_stream else ''
#    1711 )
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1493, in BaseApiClient._request(self, http_request, http_options, stream)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
# -> 1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1495 return self._retry(self._request_once, http_request, stream)
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~/anaconda3/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/anaconda3/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1472, in BaseApiClient._request_once(self, http_request, stream)
#    1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use a newer model for the latest features and improvements.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[7], line 27
#       6 model = init_chat_model(
#       7     "gemini-2.5-flash",
#       8     model_provider="google_genai",
#       9     temperature=0.7,
#      10 )
#      12 prompt = """
#      13 Write a professional email.
#      14
#    (...)     24 - Closing
#      25 """
# ---> 27 response = model.invoke(prompt)
#      29 print("=" * 60)
#      30 print("AI GENERATED EMAIL")
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:2791, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2788         msg = "Tools are already defined.code_execution tool can't be defined"
#    2789         raise ValueError(msg)
# -> 2791 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3383, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
# -> 3383     _handle_client_error(e, request)
#    3385 return _response_to_result(response)
#
# File ~/anaconda3/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:177, in _handle_client_error(e, request)
#     175 model_name = request.get("model", "unknown")
#     176 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 177 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use a newer model for the latest features and improvements.', 'status': 'NOT_FOUND'}}
