# %%
import cv2
import os
from datetime import datetime


# ============================
# Create folder for saved faces
# ============================

save_folder = "faces"

if not os.path.exists(save_folder):
    os.makedirs(save_folder)


# ============================
# Load Haar Cascade Face Detector
# ============================

face_detector = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    "haarcascade_frontalface_default.xml"
)


# Check detector
if face_detector.empty():
    print("Face detector failed to load")
    exit()

print("Face detector loaded successfully")


# ============================
# Open Webcam
# ============================

camera = cv2.VideoCapture(0)


if not camera.isOpened():
    print("Cannot open camera")
    exit()


captured = False


# ============================
# Real-time Detection
# ============================

while True:

    ret, frame = camera.read()

    if not ret:
        print("Cannot read frame")
        break


    # Convert BGR to grayscale

    gray = cv2.cvtColor(
        frame,
        cv2.COLOR_BGR2GRAY
    )


    # Detect faces

    faces = face_detector.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )


    # Draw rectangle and save image

    for (x, y, w, h) in faces:

        cv2.rectangle(
            frame,
            (x, y),
            (x+w, y+h),
            (0, 255, 0),
            2
        )


        # Take picture only once

        if not captured:

            timestamp = datetime.now().strftime(
                "%Y-%m-%d_%H-%M-%S"
            )


            filename = (
                f"{save_folder}/face_{timestamp}.jpg"
            )


            cv2.imwrite(
                filename,
                frame
            )


            print("Face detected!")
            print("Saved:", filename)


            captured = True



    # Display camera

    cv2.imshow(
        "Face Detector",
        frame
    )


    # Press q to exit

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break



# Release

camera.release()

cv2.destroyAllWindows()
# Out:
# Face detector loaded successfully
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
#
# QObject::moveToThread: Current thread (0x16a093f0) is not the object's thread (0x17107420).
# Cannot move to target thread (0x16a093f0)
# Face detected!
# Saved: faces/face_2026-08-05_02-15-44.jpg

# %%
import cv2

face_detector = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    "haarcascade_frontalface_default.xml"
)

print(face_detector.empty())
# Out:
# False
